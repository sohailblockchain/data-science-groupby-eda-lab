# %% [markdown]
# # GroupBy Practical Lab

# %%
# import pandasimport pandas as pd

# %%
# load datadf = pd.read_csv('groupby_lab_dataset.csv')df.head()

# %%
# groupby meandf.groupby('City')['Price'].mean()

# %%
# multiple aggdf.groupby('City')['Price'].agg(['mean','max','min'])

# %%
# multi column groupdf.groupby(['City','Gender'])['Price'].mean()

# %%
# pivot tablepd.pivot_table(df, values='Price', index='City', columns='Gender', aggfunc='mean')
